# %% [markdown]
# https://github.com/brucewayne-00/DSML

# %% [markdown]
# https://github.com/steve01x/DSML_PR

# %% [markdown]
#  1. Perform the following operations using Python on a data set : read data
#  from different formats(like csv, xls),indexing and selecting data, sort data,
#  describe attributes of data, checking data types of each column. (Use
#  Titanic Dataset).

# %%
# Program 1

import pandas as pd

# Read from different formats
df_csv = pd.read_csv("Titanic-Dataset.csv")
# df_xls = pd.read_excel("titanic.xls")  # uncomment if you have xls

print("First 5 rows:")
print(df_csv.head())

# Indexing and selecting data
print("\nSelect 'Name' and 'Age' columns:")
print(df_csv[['Name', 'Age']].head())

print("\nRows 10 to 15:")
print(df_csv.iloc[10:16])

# Sort data
print("\nSorted by Age:")
print(df_csv.sort_values(by='Age').head())

# Describe attributes
print("\nDescribe numeric columns:")
print(df_csv.describe())

print("\nDescribe all columns:")
print(df_csv.describe(include='all'))

# Data types of each column
print("\nData types of each column:")
print(df_csv.dtypes)
# Out:
# First 5 rows:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# 2. Perform the following operations using Python on the Telecom_Churn
#  dataset. Compute and display summary statistics for each feature available
#  in the dataset using separate commands for each statistic. (e.g. minimum
#  value, maximum value, mean, range, standard deviation, variance and
#  percentiles)

# %%
# Program 2
import pandas as pd

df = pd.read_csv("churn-bigml-80.csv")

# Display first few rows (optional)
print(df.head(), "\n")

# Compute summary statistics separately for each numeric column
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in numeric_cols:
    print(f"===== Statistics for: {col} =====")
    
    print("Minimum:", df[col].min())
    print("Maximum:", df[col].max())
    print("Mean:", df[col].mean())
    print("Range:", df[col].max() - df[col].min())
    print("Standard Deviation:", df[col].std())
    print("Variance:", df[col].var())
    print("25th Percentile:", df[col].quantile(0.25))
    print("50th Percentile (Median):", df[col].quantile(0.50))
    print("75th Percentile:", df[col].quantile(0.75))
    
    print("\n")
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# 3. Perform the following operations using Python on the data set
#  House_Price Prediction dataset. Compute standard deviation, variance and
#  percentiles using separate commands, for each feature. Create a histogram
#  for each feature in the dataset to illustrate the feature distributions.

# %%
# Program 3

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Housing.csv")

print(df.head(), "\n")

# Select numeric columns only
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Compute statistics for each numeric feature
for col in numeric_cols:
    print(f"===== Statistics for: {col} =====")
    print("Standard Deviation:", df[col].std())
    print("Variance:", df[col].var())
    print("25th Percentile:", df[col].quantile(0.25))
    print("50th Percentile (Median):", df[col].quantile(0.50))
    print("75th Percentile:", df[col].quantile(0.75))
    print("\n")

    # Create histogram for each numeric column
    
    plt.figure(figsize=(6,4))
    plt.hist(df[col], bins=20)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
#
# ===== Statistics for: price =====
# Standard Deviation: 1870439.6156573922
# ...

# %% [markdown]
# So when you write:
#
# plt.hist(series, bins=20)
#
#
# You are telling Matplotlib:
#
# 👉 “Split the X-axis into 20 intervals.”
# 👉 “Count how many data points fall in each interval and plot that on the Y-axis.”
#
# 📌 Summary
#
# Bins → X-axis (value ranges)
#
# Frequency → Y-axis (counts of data in each bin)
#
# 📊 Visual interpretation
#
# If your data ranges from 0 to 100 and bins=20:
#
# The X-axis will be divided into 20 segments (each 5 units wide).
#
# The height (Y-axis) of each bar shows how many values fall in that range.

# %% [markdown]
# ------
# 4. Write a program to do: A dataset collected in a cosmetics shop showing
#  details of customers and whether or not they responded to a special offer
#  to buy a new lip-stick is shown in table below. (Implement step by step
#  using commands- Dont use library) Use this dataset to build a decision
#  tree, with Buys as the target variable, to help in buying lipsticks in the
#  future. Find the root node of the decision tree.

# %%
# Program 4
# Build decision tree root node manually (entropy & information gain)

import math
import pandas as pd

# Example structure – replace rows with your actual dataset
data = [
    # {"Age": "<21", "Income": "High", "Gender": "Female", "MaritalStatus": "Single", "Buys": "Yes"},
    # ...
]

df = pd.DataFrame(data)

def entropy(labels):
    probs = labels.value_counts(normalize=True)
    return -sum(p * math.log2(p) for p in probs)

def info_gain(df, attribute, target):
    total_entropy = entropy(df[target])
    values = df[attribute].unique()
    weighted_entropy = 0.0
    for v in values:
        subset = df[df[attribute] == v]
        weight = len(subset) / len(df)
        weighted_entropy += weight * entropy(subset[target])
    return total_entropy - weighted_entropy

target_col = "Buys"
features = ["Age", "Income", "Gender", "MaritalStatus"]

print("Total entropy:", entropy(df[target_col]))

gains = {}
for feat in features:
    gains[feat] = info_gain(df, feat, target_col)
    print(f"Information gain for {feat}: {gains[feat]}")

root_node = max(gains, key=gains.get)
print("\nRoot node of the decision tree is:", root_node)

# %% [markdown]
# ---
# 5. Write a program to do: A dataset collected in a cosmetics shop showing
#  details of customers and whether or not they responded to a special offer
#  to buy a newlip-stick is shown in table below. (Use library commands)
#  According to the decision tree you have made from the previous training
#  data set, what is the decision for the test data: [Age < 21, Income = Low,
#  Gender = Female, Marital Status = Married]?
#   6. Write a program to do: A dataset collected in a cosmetics shop showing
#  details of customers and whether or not they responded to a special offer
#  to buy a newlip-stick is shown in table below. (Use library commands)
#  According to the decision tree you have made from the previous training
#  data set, what is the decision for the test data: [Age > 35, Income =
#  Medium, Gender = Female, Marital Status = Married]?
# 7. Write a program to do: A dataset collected in a cosmetics shop showing
#  details of customers and whether or not they responded to a special offer
#  to buy a newlip-stick is shown in table below. (Use library commands)
#  According to the decision tree you have made from the previous training
#  data set, what is the decision for the test data: [Age > 35, Income =
#  Medium, Gender = Female, Marital Status = Married]?
#  8. Write a program to do: A dataset collected in a cosmetics shop showing
#  details of customers and whether or not they responded to a special offer
#  to buy a newlip-stick is shown in table below. (Use library commands)
#  According to the decision tree you have made from the previous training
#  data set, what is the decision for the test data: [Age = 21-35, Income = Low,
#  Gender = Male, Marital Status = Married]?

# %%
# Program 5–8

import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

# Use the same lipstick dataset (fill correctly)
# data = [
#     {"Age": "<21",   "Income": "High",   "Gender": "Female", "MaritalStatus": "Single",  "Buys": "Yes"},
#     {"Age": "<21",   "Income": "High",   "Gender": "Female", "MaritalStatus": "Married", "Buys": "Yes"},
#     {"Age": "21-35", "Income": "High",   "Gender": "Male",   "MaritalStatus": "Single",  "Buys": "Yes"},
#     {"Age": ">35",   "Income": "Medium", "Gender": "Male",   "MaritalStatus": "Single",  "Buys": "Yes"},
#     {"Age": ">35",   "Income": "Low",    "Gender": "Male",   "MaritalStatus": "Married", "Buys": "No"},
#     {"Age": ">35",   "Income": "Low",    "Gender": "Female", "MaritalStatus": "Married", "Buys": "No"},
#     {"Age": "21-35", "Income": "Low",    "Gender": "Female", "MaritalStatus": "Single",  "Buys": "Yes"},
#     {"Age": "<21",   "Income": "Medium", "Gender": "Female", "MaritalStatus": "Single",  "Buys": "Yes"},
#     {"Age": "<21",   "Income": "Low",    "Gender": "Male",   "MaritalStatus": "Single",  "Buys": "No"},
#     {"Age": ">35",   "Income": "Medium", "Gender": "Female", "MaritalStatus": "Single",  "Buys": "Yes"},
#     {"Age": "21-35", "Income": "Medium", "Gender": "Male",   "MaritalStatus": "Married", "Buys": "No"},
#     {"Age": "21-35", "Income": "High",   "Gender": "Female", "MaritalStatus": "Married", "Buys": "Yes"},
# ]


df = pd.DataFrame(data)

X = df[["Age", "Income", "Gender", "MaritalStatus"]]
y = df["Buys"]

# Encode categorical features
encoders = {}
for col in X.columns:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])
    encoders[col] = le

target_encoder = LabelEncoder()
y_encoded = target_encoder.fit_transform(y)

clf = DecisionTreeClassifier(criterion="entropy", random_state=0)
clf.fit(X, y_encoded)

def encode_sample(sample_dict):
    row = []
    for col in X.columns:
        row.append(encoders[col].transform([sample_dict[col]])[0])
    return [row]

def predict_buys(sample_dict):
    encoded_row = encode_sample(sample_dict)
    pred_encoded = clf.predict(encoded_row)[0]#Use the decision tree to get the numeric prediction (0 or 1).
    return target_encoder.inverse_transform([pred_encoded])[0]#Convert numeric prediction → original label ("Yes"/"No") and return it.

# Q5: [Age < 21, Income = Low, Gender = Female, Marital Status = Married]
sample_q5 = {"Age": "<21", "Income": "Low", "Gender": "Female", "MaritalStatus": "Married"}
print("Q5 Decision:", predict_buys(sample_q5))

# Q6/Q7: [Age > 35, Income = Medium, Gender = Female, Marital Status = Married]
sample_q6 = {"Age": ">35", "Income": "Medium", "Gender": "Female", "MaritalStatus": "Married"}
print("Q6/Q7 Decision:", predict_buys(sample_q6))

# Q8: [Age = 21-35, Income = Low, Gender = Male, Marital Status = Married]
sample_q8 = {"Age": "21-35", "Income": "Low", "Gender": "Male", "MaritalStatus": "Married"}
print("Q8 Decision:", predict_buys(sample_q8))

# %% [markdown]
# ---
# 9. Write a program to do the following: You have given a collection of 8
#  points. P1=[0.1,0.6] P2=[0.15,0.71] P3=[0.08,0.9] P4=[0.16, 0.85]
#  P5=[0.2,0.3] P6=[0.25,0.5] P7=[0.24,0.1] P8=[0.3,0.2]. Perform the k-mean
#  clustering with initial centroids as m1=P1 =Cluster#1=C1 and
#  m2=P8=cluster#2=C2. Answer the following 1] Which cluster does P6
#  belong to? 2] What is the population of a cluster around m2? 3] What is
#  the updated value of m1 and m2?

# %%
# # Program 9

import numpy as np

points = np.array([
    [0.1, 0.6],   # P1
    [0.15, 0.71], # P2
    [0.08, 0.9],  # P3
    [0.16, 0.85], # P4
    [0.2, 0.3],   # P5
    [0.25, 0.5],  # P6
    [0.24, 0.1],  # P7
    [0.3, 0.2]    # P8
])

# initial centroids: m1 = P1, m2 = P8
m1 = points[0].copy()
m2 = points[7].copy()

def distance_formula(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

def assign_clusters(points, c1, c2):
    clusters = {1: [], 2: []}
    for i, p in enumerate(points):
        d1 = distance_formula(p, c1)
        d2 = distance_formula(p, c2)
        if d1 < d2:
            clusters[1].append(i)
        else:
            clusters[2].append(i)
    return clusters

def recompute_centroid(points, indices):
    if len(indices) == 0:
        return None
    return np.mean(points[indices], axis=0)

clusters = assign_clusters(points, m1, m2)
print("Initial clusters:", clusters)

m1_new = recompute_centroid(points, clusters[1])
m2_new = recompute_centroid(points, clusters[2])

print("Updated m1:", m1_new)
print("Updated m2:", m2_new)

# Answers:
print("1] Which cluster does P6 belong to?")
for c, idxs in clusters.items():
    if 5 in idxs:  # P6 index = 5
        print("P6 belongs to cluster:", c)

print("2] Population around m2 (cluster 2):", len(clusters[2]))
print("3] Updated m1 and m2:", m1_new, m2_new)

# ----



import math

# Points
P = [(0.1,0.6),(0.15,0.71),(0.08,0.9),(0.16,0.85),
     (0.2,0.3),(0.25,0.5),(0.24,0.1),(0.3,0.2)]

# Initial centroids
m1 = P[0]   # P1
m2 = P[7]   # P8

# Assign each point to nearest cluster
C1, C2 = [], []       
for p in P:
    d1 = math.dist(p, m1)
    d2 = math.dist(p, m2)
    (C1 if d1 < d2 else C2).append(p)

# Update centroids
m1_new = (sum(x for x,y in C1)/len(C1),  sum(y for x,y in C1)/len(C1))
m2_new = (sum(x for x,y in C2)/len(C2),  sum(y for x,y in C2)/len(C2))

print("Cluster 1:", C1)
print("Cluster 2:", C2)
print("\nUpdated m1:", m1_new)
print("Updated m2:", m2_new)

# Answer: Where is P6?
print("\nP6 belongs to:", "Cluster 1" if P[5] in C1 else "Cluster 2")
print("Population of cluster around m2:", len(C2))
# Out:
#   Cell In[12], line 53
#     ----
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ---
# 10. Write a program to do the following: You have given a collection of 8
#  points. P1=[2, 10] P2=[2, 5] P3=[8, 4] P4=[5, 8] P5=[7,5] P6=[6, 4] P7=[1, 2]
#  P8=[4, 9]. Perform the k-mean clustering with initial centroids as m1=P1
#  =Cluster#1=C1 and m2=P4=cluster#2=C2, m3=P7 =Cluster#3=C3. Answer
#  the following 1] Which cluster does P6 belong to? 2] What is the
#  population of a cluster around m3? 3] What is the updated value of m1,
#  m2, m3?

# %%
# Program 10

import numpy as np

points = np.array([
    [2, 10], # P1
    [2, 5],  # P2
    [8, 4],  # P3
    [5, 8],  # P4
    [7, 5],  # P5
    [6, 4],  # P6
    [1, 2],  # P7
    [4, 9]   # P8
])

# m1 = P1, m2 = P4, m3 = P7
m1 = points[0].copy()
m2 = points[3].copy()
m3 = points[6].copy()

def distance_formula(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

def assign_clusters3(points, c1, c2, c3):
    clusters = {1: [], 2: [], 3: []}
    for i, p in enumerate(points):
        d1 = distance_formula(p, c1)
        d2 = distance_formula(p, c2)
        d3 = distance_formula(p, c3)
        dmin = min(d1, d2, d3)
        if dmin == d1:
            clusters[1].append(i)
        elif dmin == d2:
            clusters[2].append(i)
        else:
            clusters[3].append(i)
    return clusters

def recompute(points, indices):
    if not indices:
        return None
    return np.mean(points[indices], axis=0)

clusters = assign_clusters3(points, m1, m2, m3)
print("Initial clusters:", clusters)

m1_new = recompute(points, clusters[1])
m2_new = recompute(points, clusters[2])
m3_new = recompute(points, clusters[3])

print("Updated centroids:")
print("m1:", m1_new)
print("m2:", m2_new)
print("m3:", m3_new)

# Answers
print("1] Cluster of P6:")
for c, idxs in clusters.items():
    if 5 in idxs:  # P6 index = 5
        print("P6 belongs to cluster:", c)

print("2] Population around m3 (cluster 3):", len(clusters[3]))
print("3] Updated m1, m2, m3:", m1_new, m2_new, m3_new)
# Out:
# Initial clusters: {1: [0], 2: [2, 3, 4, 5, 7], 3: [1, 6]}
# Updated centroids:
# m1: [ 2. 10.]
# m2: [6. 6.]
# m3: [1.5 3.5]
# 1] Cluster of P6:
# P6 belongs to cluster: 2
# 2] Population around m3 (cluster 3): 2
# 3] Updated m1, m2, m3: [ 2. 10.] [6. 6.] [1.5 3.5]

# %% [markdown]
# ----
# 11. Use Iris flower dataset and perform following :
# i. List down the features and their types (e.g., numeric, nominal)
#  available in the dataset.
# ii. Create a histogram for each feature in the
#  dataset to illustrate the feature distributions.

# %%
# Program 11

import seaborn as sns
import matplotlib.pyplot as plt

iris = sns.load_dataset("iris")
print("Columns and dtypes:")
print(iris.dtypes)

# Feature type discussion:
for col in iris.columns:
    if iris[col].dtype == 'float64' or iris[col].dtype == 'int64':
        print(col, "-> Numeric")
    else:
        print(col, "-> Nominal")

# Histograms
numeric_cols = iris.select_dtypes(include=['float64', 'int64']).columns

for col in numeric_cols:
    plt.figure()
    plt.hist(iris[col], bins=15)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()
# Out:
# Columns and dtypes:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object
# sepal_length -> Numeric
# sepal_width -> Numeric
# petal_length -> Numeric
# petal_width -> Numeric
# species -> Nominal

# %% [markdown]
# 12.Use Iris flower dataset and perform following :
#  1. Create a box plot for each feature in the dataset.
#  2. Identify and discuss distributions and identify outliers from them.

# %%
# Program 12

import seaborn as sns
import matplotlib.pyplot as plt

iris = sns.load_dataset("iris")
numeric_cols = iris.select_dtypes(include=['float64', 'int64']).columns

for col in numeric_cols:
    plt.figure()
    sns.boxplot(x=iris[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# Outliers can be observed on the plots – in report, mention any points outside whiskers.

# %% [markdown]
# 13. Use the covid_vaccine_statewise.csv dataset and perform the following analytics. :
#  a. Describe the dataset
#  b. Number of persons state wise vaccinated for first dose in India
#  c. Number of persons state wise vaccinated for second dose in India

# %%
# Program 13

df=pd.read_csv("COVID-19 India Statewise Vaccine Data.csv")

print("Describe dataset:")
print(df.describe(include='all'))

dose1=df.groupby("State/UTs")["Dose1"].sum().reset_index()
dose2=df.groupby("State/UTs")["Dose2"].sum().reset_index()

print("\nState-wise First Dose:")
print(dose1.to_string())

print("\nState-wise Second Dose:")
print(dose2)
# Out:
# Describe dataset:
#                   State/UTs  Total Vaccination Doses         Dose1  \
# count                    36             3.600000e+01  3.600000e+01
# unique                   36                      NaN           NaN
# top     Andaman And Nicobar                      NaN           NaN
# freq                      1                      NaN           NaN
# mean                    NaN             6.115204e+07  2.555900e+07
# std                     NaN             7.945565e+07  3.235136e+07
# min                     NaN             1.453130e+05  5.691400e+04
# 25%                     NaN             2.287468e+06  1.045788e+06
# 50%                     NaN             4.064265e+07  1.778092e+07
# 75%                     NaN             1.121485e+08  4.281551e+07
# max                     NaN             3.920112e+08  1.540970e+08
#
#                Dose2  Dose 1 15-18  Dose 2 15-18  Dose 1 12-14  Dose 2 12-14  \
# ...

# %% [markdown]
# 14. Use the covid_vaccine_statewise.csv dataset and perform the following analytics.
#  A. Describe the dataset.
#  B. Number of Males vaccinated.
#  C. Number of females vaccinated.

# %%
# Program 14

import pandas as pd

df = pd.read_csv("covid_vaccine_statewise.csv")

print("Describe dataset:")
print(df.describe(include='all'))

# Assume columns: 'Male(Individuals Vaccinated)', 'Female(Individuals Vaccinated)'
total_males = df["Male(Individuals Vaccinated)"].sum()
total_females = df["Female(Individuals Vaccinated)"].sum()

print("Total Males vaccinated:", total_males)
print("Total Females vaccinated:", total_females)

# %% [markdown]
# 15. Use the dataset 'titanic'. The dataset contains 891 rows and contains
#  information about the passengers who boarded the unfortunate Titanic
#  ship. Use the Seaborn library to see if we can find any patterns in the data.

# %%
# Program 15

import seaborn as sns
import matplotlib.pyplot as plt

titanic = sns.load_dataset("titanic")

# Example patterns
sns.countplot(x="sex", hue="survived", data=titanic)
plt.title("Survival by Sex")
plt.show()

sns.countplot(x="class", hue="survived", data=titanic)
plt.title("Survival by Class")
plt.show()

sns.boxplot(x="class", y="age", data=titanic)
plt.title("Age distribution by Class")
plt.show()

# %% [markdown]
#  16. Use the inbuilt dataset 'titanic'. The dataset contains 891 rows and
#  contains information about the passengers who boarded the unfortunate
#  Titanic ship. Write a code to check how the price of the ticket (column
#  name: 'fare') for each passenger is distributed by plotting a histogram.

# %%
# Program 16

import seaborn as sns
import matplotlib.pyplot as plt

titanic = sns.load_dataset("titanic")

plt.figure(figsize=(6,4))
plt.hist(titanic["fare"].dropna(), bins=30)
plt.title("Distribution of Fare")
plt.xlabel("Fare")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 17) Metrics from confusion matrix (TP=1, FP=1, FN=8, TN=90)

# %%
# Program 17

TP = 1
FP = 1
FN = 8
TN = 90

accuracy = (TP + TN) / (TP + TN + FP + FN)
error_rate = (1 - accuracy)*100
precision = TP / (TP + FP)
recall = TP / (TP + FN)

print("Accuracy:", accuracy*100,"%")
print("Error Rate:", error_rate,"%")
print("Precision:", precision)
print("Recall:", recall)
# Out:
# Accuracy: 91.0 %
# Error Rate: 8.999999999999996 %
# Precision: 0.5
# Recall: 0.1111111111111111

# %% [markdown]
# 18. Use House_Price prediction dataset. Provide summary statistics (mean,
#  median, minimum, maximum, standard deviation) of variables (categorical
#  vs quantitative) such as- For example, if categorical variable is age groups
#  and quantitative variable is income, then provide summary statistics of
#  income grouped by the age groups

# %%
# Program 18

import pandas as pd

df = pd.read_csv("Housing.csv")

# Example: Categorical = 'Age_Group', Quantitative = 'Income'
# Replace with actual column names you have.
# cat_col = "furnishingstatus"
# quant_col = "area"

# grouped = df.groupby(cat_col)[quant_col]
# summary = grouped.agg(['mean', 'median', 'min', 'max', 'std'])
# print(summary)

#---

print(df.head(), "\n")

# Identify categorical and numerical columns
categorical_cols = df.select_dtypes(include=['object']).columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

print("Categorical Columns:\n", categorical_cols, "\n")
print("Numerical Columns:\n", numerical_cols, "\n")

for i in range(len(categorical_cols)):
    # Select one categorical column to group by (first one in dataset)
    group_column = categorical_cols[i]  # You may change this if needed

    print(f"\n===== Summary Statistics Grouped by '{group_column}' =====\n")

    summary_stats = df.groupby(group_column)[numerical_cols].agg(
        ['mean', 'median', 'min', 'max', 'std']
    )

    print(summary_stats)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
#
# Categorical Columns:
#  Index(['mainroad', 'guestroom', 'basement', 'hotwaterheating',
# ...

# %% [markdown]
# ---
# 19. Write a Python program to display some basic statistical details like
#  percentile, mean, standard deviation etc (Use python and pandas
#  commands) the species of ‘Iris-setosa’, ‘Iris-versicolor’ and ‘Iris-versicolor’
#  of iris.csv dataset.

# %%
# Program 19

import pandas as pd
import seaborn as sns

# df = pd.read_csv("iris.csv")
df = sns.load_dataset("iris")

for species_name, group in df.groupby("species"):
    print(f"\n=== Species: {species_name} ===")
    print(group.describe())  # includes mean, std, percentiles etc.
# Out:
# === Species: setosa ===
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000
#
# === Species: versicolor ===
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# ...

# %% [markdown]
# ---
#  20. Write a program to cluster a set of points using K-means for IRIS
#  dataset. Consider, K=3, clusters. Consider Euclidean distance as the
#  distance measure. Randomly initialize a cluster mean as one of the data
#  points. Iterate at least for 10 iterations. After iterations are over, print the
#  final cluster means for each of the clusters.

# %%
#bruce

# import seaborn as sns
# from sklearn.cluster import KMeans
# import pandas as pd

# # Load iris dataset
# df = sns.load_dataset("iris")

# # Use only numeric columns for clustering
# numeric_df = df.select_dtypes(include=['float64', 'int64'])

# # Define KMeans model
# kmeans = KMeans(n_clusters=3, init='random', n_init=1, max_iter=10, random_state=42)

# # Fit model
# kmeans.fit(numeric_df)

# # Print final cluster centers (means)
# print("\n===== Final Cluster Means =====\n")
# centers = pd.DataFrame(kmeans.cluster_centers_, columns=numeric_df.columns)
# print(centers)

# Program 20

import pandas as pd
import numpy as np
import seaborn as sns

def distance_formula(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

df = sns.load_dataset('iris')

X = df.iloc[:, 0:4].values  # assume first 4 are features

np.random.seed(0)
# randomly pick one point as initial mean for each cluster (K=3)
K = 3

initial_indices = np.random.choice(X.shape[0], K, replace=False)
means = X[initial_indices, :]


iterations = 10

for it in range(iterations):
    # Assignment step
    clusters = {k: [] for k in range(K)}
    for i, x in enumerate(X):
        dists = [distance_formula(x, m) for m in means]

        # replace np.argmin(dists) with pure Python
        min_dist = min(dists)
        k = dists.index(min_dist)

        clusters[k].append(i)

    # Update step
    for k in range(K):
        if clusters[k]:
            means[k] = np.mean(X[clusters[k]], axis=0)

print("Final cluster means (K=3):")
for i, m in enumerate(means):
    print(f"Cluster {i} mean:", m)
# Out:
# Final cluster means (K=3):
# Cluster 0 mean: [6.85384615 3.07692308 5.71538462 2.05384615]
# Cluster 1 mean: [5.88360656 2.74098361 4.38852459 1.43442623]
# Cluster 2 mean: [5.006 3.428 1.462 0.246]

# %% [markdown]
# ---
# 21. Write a program to cluster a set of points using K-means for IRIS
#  dataset. Consider, K=4, clusters. Consider Euclidean distance as the
#  distance measure. Randomly initialize a cluster mean as one of the data
#  points. Iterate at least for 10 iterations. After iterations are over, print the final cluster means for each of the clusters.

# %%
# Program 21

import pandas as pd
import numpy as np
import seaborn as sns

def distance_formula(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

df = sns.load_dataset('iris')

X = df.iloc[:, 0:4].values  # assume first 4 are features

np.random.seed(0)
# randomly pick one point as initial mean for each cluster (K=4)
K = 4

initial_indices = np.random.choice(X.shape[0], K, replace=False)
means = X[initial_indices, :]


iterations = 10

for it in range(iterations):
    # Assignment step
    clusters = {k: [] for k in range(K)}
    for i, x in enumerate(X):
        dists = [distance_formula(x, m) for m in means]

        # replace np.argmin(dists) with pure Python
        min_dist = min(dists)
        k = dists.index(min_dist)

        clusters[k].append(i)

    # Update step
    for k in range(K):
        if clusters[k]:
            means[k] = np.mean(X[clusters[k]], axis=0)

print("Final cluster means (K=4):")
for i, m in enumerate(means):
    print(f"Cluster {i} mean:", m)

# %% [markdown]
# ---
# 22. Metrics from cancer confusion matrix

# %%
# Program 22

# Table:
#               Pred Yes   Pred No   Total
# Actual Yes       90       210      300
# Actual No       140      9560     9700

TP = 90
FN = 210
FP = 140
TN = 9560

accuracy = (TP + TN) / (TP + TN + FP + FN)
error_rate = (1 - accuracy)*100
precision = TP / (TP + FP)
recall = TP / (TP + FN)

print("Accuracy:", accuracy*100,"%")
print("Error Rate:", error_rate,"%")
print("Precision:", precision)
print("Recall:", recall)
# Out:
# Accuracy: 96.5 %
# Error Rate: 3.500000000000003 %
# Precision: 0.391304347826087
# Recall: 0.3

# %% [markdown]
# ---
# 23.With reference to Table , obtain the Frequency table for the
#  attribute age. From the frequency table you have obtained, calculate the information gain of the frequency table while splitting on Age. (Use step by step Python/Pandas commands)

# %%
# Program 23

import math
import pandas as pd

# Data from the image
data = [
    {"Age": "Young",  "Income": "High",   "Married": "No",  "Health": "Fair", "Class": "No"},
    {"Age": "young",  "Income": "High",   "Married": "No",  "Health": "Good", "Class": "No"},
    {"Age": "Middle", "Income": "High",   "Married": "No",  "Health": "Fair", "Class": "Yes"},
    {"Age": "Old",    "Income": "Medium", "Married": "No",  "Health": "Fair", "Class": "Yes"},
    {"Age": "Old",    "Income": "Low",    "Married": "Yes", "Health": "Fair", "Class": "Yes"},
    {"Age": "Old",    "Income": "Low",    "Married": "Yes", "Health": "Good", "Class": "No"},
    {"Age": "Middle", "Income": "Low",    "Married": "Yes", "Health": "Good", "Class": "Yes"},
    {"Age": "Young",  "Income": "Medium", "Married": "No",  "Health": "Fair", "Class": "No"},
    {"Age": "Young",  "Income": "Low",    "Married": "Yes", "Health": "Fair", "Class": "Yes"},
    {"Age": "Old",    "Income": "Medium", "Married": "Yes", "Health": "Fair", "Class": "Yes"},
    {"Age": "Young",  "Income": "Medium", "Married": "Yes", "Health": "Good", "Class": "Yes"},
    {"Age": "Middle", "Income": "Medium", "Married": "No",  "Health": "Good", "Class": "Yes"},
    {"Age": "Middle", "Income": "High",   "Married": "Yes", "Health": "Fair", "Class": "Yes"},
    {"Age": "Old",    "Income": "Medium", "Married": "No",  "Health": "Good", "Class": "No"},
]

df = pd.DataFrame(data)

# Frequency table for Age vs Class
freq_table = pd.crosstab(df["Age"], df["Class"])
print("Frequency Table (Age vs Class):")
print(freq_table)

def entropy(labels):
    probs = labels.value_counts(normalize=True)
    return -sum(p * math.log2(p) for p in probs)

def info_gain(df, attribute, target):
    total_entropy = entropy(df[target])
    values = df[attribute].unique()
    weighted_entropy = 0.0
    for v in values:
        subset = df[df[attribute] == v]
        weight = len(subset) / len(df)
        weighted_entropy += weight * entropy(subset[target])
    return total_entropy - weighted_entropy

target_col = "Class"
attribute = "Age"
gain_age = info_gain(df, attribute, target_col)

print("\nInformation Gain when splitting on Age:", gain_age)
# Out:
# Frequency Table (Age vs Class):
# Class   No  Yes
# Age
# Middle   0    4
# Old      2    3
# Young    2    2
# young    1    0
#
# Information Gain when splitting on Age: 0.30780360350824953

# %% [markdown]
# ---
# 24. Perform the following operations using Python on a suitable data set, counting unique values of data, format of each column, converting variable data type (e.g. from long to short, vice versa), identifying missing values and filling in the missing values.

# %%
# Program 24

import pandas as pd
import numpy as np

df = pd.read_csv("your_dataset.csv")  # replace with actual dataset

print("Unique counts per column:")
for col in df.columns:
    print(col, "->", df[col].nunique())

print("\nData types and formats:")
print(df.dtypes)

# Convert data type example:
# long int -> float / int
# Suppose 'some_col' is float but we want int:
# df['some_col'] = df['some_col'].astype(int)

# Missing values
print("\nMissing values per column:")
print(df.isna().sum())

# Fill missing numeric with mean, categorical with mode
for col in df.columns:
    if df[col].isna().sum() > 0:
        if pd.api.types.is_numeric_dtype(df[col]):
            df[col].fillna(df[col].mean(), inplace=True)
        else:
            df[col].fillna(df[col].mode()[0], inplace=True)

print("\nAfter filling missing values:")
print(df.isna().sum())

# %% [markdown]
# 25. Perform Data Cleaning, Data transformation using Python on any data set.

# %%
# Program 25

import pandas as pd

df = pd.read_csv("your_dataset.csv")  # replace

print("Original shape:", df.shape)

# 1. Remove duplicate rows
df = df.drop_duplicates()
print("After dropping duplicates:", df.shape)

# 2. Handle missing values
for col in df.columns:
    if df[col].isna().sum() > 0:
        if pd.api.types.is_numeric_dtype(df[col]):
            df[col].fillna(df[col].median(), inplace=True)
        else:
            df[col].fillna("Unknown", inplace=True)

# 3. Remove outliers using IQR for a numeric column as example
num_cols = df.select_dtypes(include=['float64', 'int64']).columns
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    df = df[(df[col] >= lower) & (df[col] <= upper)]

print("After removing outliers:", df.shape)

# 4. Data transformation – normalization / standardization
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df_scaled = df.copy()
df_scaled[num_cols] = scaler.fit_transform(df[num_cols])

print("Final cleaned & transformed data:")
print(df_scaled.head())
